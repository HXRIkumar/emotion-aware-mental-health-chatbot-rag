# %% [markdown]
# <a href="https://colab.research.google.com/github/HXRIkumar/emotion-aware-mental-health-chatbot-rag/blob/main/Mental_Health_Chatbot(New_V1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install dependencies
# !pip install -q sentence-transformers chromadb gradio requests

print("✅ Setup complete!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Setup complete!

# %%
import sys
sys.path.append('/content/drive/MyDrive/mental_health_chatbot/src')

print("✅ Path configured!")
# Out:
# ✅ Path configured!

# %%
# %run /content/drive/MyDrive/mental_health_chatbot/main.py
# Out:
# Initializing chatbot...
#
# ...
# 🧠 INITIALIZING MENTAL HEALTH CHATBOT (UPGRADED)
# ...
#
# 1️⃣ Setting up RAG Engine...
# 🔄 Loading embedding model: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ RAG Engine initialized
#
# ...
# SETTING UP RAG ENGINE
# ...
# 🗑️  Deleted old intents collection
# ✅ Loaded 50 intents
# ✅ Intents collection created with 50 entries
# 🗑️  Deleted old memes collection
# ✅ Loaded 10 memes
# ✅ Memes collection created with 10 entries
#
# ✅ RAG Engine setup complete!
# ...
#
#
# 2️⃣ Setting up Emotion Detector...
# ✅ Emotion detector ready (with confidence scoring)
#
# ...
